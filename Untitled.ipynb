# %%
import os, sys
import numpy as np
import pandas as pd
import pandas_profiling
import codecs

# %%
def numResults(str):
    if(str=="No results"):
        return 0
    else:
        # Quitar "Cerca de"
        str = str.replace("Cerca de", "")
        # Obtener el número
        str = str.split()
        num= str[0]
        num = num.replace(",", "")
        return int(num)

# %%
numResults("No results")
# Out:
# 0

# %%
with codecs.open('positive_words_es.txt','r',encoding='utf8') as f:
    text= f.read()

# %%
text.split('\r\n')
# Out:
# ['como',
#  'gran',
#  'mayor',
#  'nuevo',
#  'general',
#  'obra',
#  'principal',
#  'bien',
#  'poco',
#  'trabajo',
#  'importante',
#  'mejor',
#  'obras',
#  'cerca',
#  'éxito',
#  'acuerdo',
#  'pues',
#  'propio',
#  'original',
#  'igual',
#  'cuerpo',
#  'primero',
#  'servicio',
#  'modo',
#  'principios',
#  'gracias',
#  'personaje',
#  'dirección',
#  'superior',
#  'personajes',
#  'apoyo',
#  'capacidad',
#  'derecho',
#  'real',
#  'grande',
#  'realizar',
#  'firme',
#  'profesional',
#  'similar',
#  'libre',
#  'sentido',
#  'respecto',
#  'mejores',
#  'sencillo',
#  'características',
#  'influencia',
#  'valor',
#  'favor',
#  'energía',
#  'oro',
#  'dicha',
#  'considerado',
#  'alcanzar',
#  'victoria',
#  'honor',
#  'premio',
#  'nada',
#  'amor',
#  'realizado',
#  'bastante',
#  'campeón',
#  'trabajar',
#  'educación',
#  'derecha',
#  'líder',
#  'pasar',
#  'mil',
#  'unidad',
#  'prueba',
#  'contrato',
#  'libertad',
#  'completo',
#  'llevar',
#  'pronto',
#  'rápidamente',
#  'ganar',
#  'completamente',
#  'famoso',
#  'máximo',
#  'capaz',
#  'conseguir',
#  'maestro',
#  'ganado',
#  'paz',
#  'humano',
#  'vivo',
#  'variedad',
#  'protección',
#  'premios',
#  'claro',
#  'destaca',
#  'económico',
#  'derrota',
#  'Grande',
#  'right',
#  'propuesta',
#  'destino',
#  'corazón',
#  'cabecera',
#  'intención',
#  'grabado',
#  'lograr',
#  'reconocido',
#  'producir',
#  'señor',
#  'ayudar',
#  'dedicado',
#  'clásico',
#  'llevado',
#  'dulce',
#  'suficiente',
#  'verdad',
#  'fama',
#  'destacado',
#  'ganador',
#  'top',
#  'éxitos',
#  'cubierta',
#  'breve',
#  'rápido',
#  'notable',
#  'mejorar',
#  'disponible',
#  'verdadero',
#  'abogado',
#  'inmediatamente',
#  'activo',
#  'amplio',
#  'reforma',
#  'fácil',
#  'homenaje',
#  'justo',
#  'moderno',
#  'intereses',
#  'representante',
#  'cumplir',
#  'triunfo',
#  'salvo',
#  'ganando',
#  'pensamiento',
#  'fortaleza',
#  'amistad',
#  'ampliamente',
#  'recuperar',
#  'derrotado',
#  'jugando',
#  'belleza',
#  'fe',
#  'legal',
#  'alianza',
#  'igualmente',
#  'celebración',
#  'claramente',
#  'fácilmente',
#  'suerte',
#  'habilidad',
#  'cielo',
#  'proteger',
#  'considerar',
#  'justicia',
#  'disposición',
#  'deportivo',
#  'aumentar',
#  'supuesto',
#  'calor',
#  'integrado',
#  'ventaja',
#  'oferta',
#  'logrado',
#  'caballería',
#  'soporte',
#  'patrón',
#  'riqueza',
#  'excelente',
#  'comenzar',
#  'reformas',
#  'brillante',
#  'derrotar',
#  'seguro',
#  'moral',
#  'recuperación',
#  'precisamente',
#  'fans',
#  'útil',
#  'inteligencia',
#  'juvenil',
#  'trabajado',
#  'mejora',
#  'bueno',
#  'confianza',
#  'liberación',
#  'defender',
#  'declaración',
#  'noble',
#  'considerable',
#  'gana',
#  'maestros',
#  'interesante',
#  'ideal',
#  'superar',
#  'santo',
#  'equilibrio',
#  'talento',
#  'gusto',
#  'héroe',
#  'cima',
#  'cero',
#  'aprobación',
#  'humor',
#  'celebrado',
#  'prestigio',
#  'intelectual',
#  'poderoso',
#  'profundo',
#  'paciente',
#  'beneficios',
#  'ofrecer',
#  'compromiso',
#  'inspiración',
#  'apoyar',
#  'espiritual',
#  'esperar',
#  'célebre',
#  'flor',
#  'detenido',
#  'exactamente',
#  'alimento',
#  'asegurar',
#  'sorpresa',
#  'añadir',
#  'completar',
#  'amante',
#  'beneficio',
#  'abundante',
#  'cable',
#  'demuestra',
#  'extremadamente',
#  'mejoras',
#  'virtud',
#  'rico',
#  'otorgado',
#  'adecuado',
#  'visible',
#  'suficientemente',
#  'estable',
#  'contraste',
#  'fortuna',
#  'logro',
#  'secundario',
#  'conduce',
#  'impulso',
#  'impresión',
#  'continuidad',
#  'distinción',
#  'correcto',
#  'aprobado',
#  'afluente',
#  'saludo',
#  'facilidad',
#  'realista',
#  'subir',
#  'facilitar',
#  'progreso',
#  'magia',
#  'conforme',
#  'caliente',
#  'estabilidad',
#  'definido',
#  'celebrar',
#  'pasión',
#  'auge',
#  'recurso',
#  'funcionar',
#  'formalmente',
#  'fiel',
#  'logros',
#  'dispuesto',
#  'revolucionario',
#  'suave',
#  'prima',
#  'adecuada',
#  'aviso',
#  'novio',
#  'sensación',
#  'perfectamente',
#  'liberado',
#  'integral',
#  'atracción',
#  'Renacimiento',
#  'elaborado',
#  'defensor',
#  'ganadora',
#  'positivo',
#  'diplomático',
#  'preparar',
#  'profundamente',
#  'apreciar',
#  'apoyado',
#  'atractivo',
#  'favorable',
#  'notablemente',
#  'contribución',
#  'significativo',
#  'probar',
#  'avances',
#  'ordenado',
#  'creer',
#  'ligero',
#  'cumplimiento',
#  'trato',
#  'pendiente',
#  'potente',
#  'ventajas',
#  'abundancia',
#  'operar',
#  'extenso',
#  'crédito',
#  'fresco',
#  'cura',
#  'dinámica',
#  'feliz',
#  'defensores',
#  'consistente',
#  'perfecto',
#  'ganadores',
#  'capturar',
#  'lujo',
#  'elevación',
#  'sólido',
#  'semejante',
#  'silencio',
#  'pacto',
#  'franco',
#  'instrumental',
#  'ejemplar',
#  'preparado',
#  'estelar',
#  'garantizar',
#  'renacentista',
#  'eficaz',
#  'inteligente',
#  'afición',
#  'disfrutar',
#  'mina',
#  'experto',
#  'vencedor',
#  'aporte',
#  'puro',
#  'apoya',
#  'levantar',
#  'ánimo',
#  'comprender',
#  'correctamente',
#  'designar',
#  'supervivencia',
#  'superado',
#  'ama',
#  'dorado',
#  'seguramente',
#  'comprensión',
#  'amistoso',
#  'eficacia',
#  'atraer',
#  'fantasía',
#  'preciso',
#  'conducir',
#  'obligación',
#  'madrugada',
#  'avanzado',
#  'fijo',
#  'eficiente',
#  'pura',
#  'enamorado',
#  'santa',
#  'derrotas',
#  'masivo',
#  'promesa',
#  'favorito',
#  'élite',
#  'armonía',
#  'lealtad',
#  'monumental',
#  'renombre',
#  'respaldo',
#  'limpieza',
#  'madurez',
#  'conveniente',
#  'pozo',
#  'ángel',
#  'bienestar',
#  'acogida',
#  'excepcional',
#  'plomo',
#  'adaptado',
#  'legendario',
#  'influyente',
#  'segura',
#  'gloria',
#  'impresionante',
#  'romántica',
#  'cálido',
#  'espectacular',
#  'afirmación',
#  'aprecia',
#  'esplendor',
#  'querido',
#  'excelencia',
#  'abiertamente',
#  'tracción',
#  'alegría',
#  'satisfacer',
#  'prefiere',
#  'aplicado',
#  'positivos',
#  'querer',
#  'efectuar',
#  'sagrado',
#  'entusiasmo',
#  'privilegio',
#  'brillo',
#  'ayudado',
#  'dignidad',
#  'trofeo',
#  'innovación',
#  'extraordinario',
#  'auténtico',
#  'reforzar',
#  'sensible',
#  'mágico',
#  'gracia',
#  'romántico',
#  'superioridad',
#  'accesible',
#  'joyas',
#  'curioso',
#  'negociar',
#  'renombrado',
#  'prestigioso',
#  'superó',
#  'decisivo',
#  'moverse',
#  'restaurar',
#  'compatible',
#  'felicidad',
#  'portavoz',
#  'agradable',
#  'fomentar',
#  'convenio',
#  'apropiado',
#  'trabajador',
#  'fluido',
#  'emociones',
#  'dominar',
#  'lógico',
#  'ganancias',
#  'maestría',
#  'fidelidad',
#  'aficionado',
#  'prominente',
#  'orgullo',
#  'inofensivo',
#  'enteramente',
#  'sorprendente',
#  'celeste',
#  'revolucionaria',
#  'protector',
#  'tapa',
#  'indicado',
#  'complemento',
#  'legalmente',
#  'galardón',
#  'admiración',
#  'sostenido',
#  'Magno',
#  'mejorado',
#  'renacimiento',
#  'elegante',
#  'supremo',
#  'promotor',
#  'placer',
#  'prosperidad',
#  'talentos',
#  'listo',
#  'reconocimientos',
#  'revelación',
#  'deber',
#  'resistente',
#  'azar',
#  'dominado',
#  'dotado',
#  'distintivo',
#  'apogeo',
#  'restaurado',
#  'certeza',
#  'exacto',
#  'sostener',
#  'recto',
#  'autónomo',
#  'integridad',
#  'corregir',
#  'domina',
#  'genio',
#  'mérito',
#  'empuje',
#  'ayudando',
#  'agudo',
#  'perdón',
#  'fino',
#  'sonda',
#  'racional',
#  'enamorada',
#  'amanecer',
#  'alegre',
#  'perfección',
#  'novedad',
#  'ilustración',
#  'cumplido',
#  'impulsar',
#  'hermoso',
#  'aclarar',
#  'ilustre',
#  'claridad',
#  'sabiduría',
#  'distinguido',
#  'divino',
#  'mono',
#  'solidaridad',
#  'facilita',
#  'amo',
#  'legítimo',
#  'libertades',
#  'cariño',
#  'garantía',
#  'animado',
#  'bello',
#  'penetración',
#  'creativo',
#  'práctico',
#  'educado',
#  'sabio',
#  'leal',
#  'renovado',
#  'balas',
#  'gratuito',
#  'delgado',
#  'inocente',
#  'heroína',
#  'ambicioso',
#  'ingenio',
#  'calificado',
#  'merced',
#  'afecto',
#  'premiado',
#  'bienvenida',
#  'fértil',
#  'probado',
#  'flexible',
#  'ahorro',
#  'informativo',
#  'super',
#  'basta',
#  'satisfacción',
#  'dinámico',
#  'justamente',
#  'recomendación',
#  'marchar',
#  'emoción',
#  'valioso',
#  'respetar',
#  'gustos',
#  'ídolo',
#  'sostenible',
#  'diversión',
#  'favorecer',
#  'prometido',
#  'tranquilidad',
#  'entendido',
#  'valiente',
#  'agradecimiento',
#  'aprobar',
#  'cargado',
#  'resuelto',
#  'amable',
#  'garantías',
#  'promesas',
#  'creativa',
#  'transparente',
#  'suceder',
#  'recomendaciones',
#  'paraíso',
#  'tranquilo',
#  'elevar',
#  'preferencias',
#  'milagro',
#  'trompeta',
#  'pastel',
#  'afinidad',
#  'preferido',
#  'innovador',
#  'fiable',
#  'reclamar',
#  'curar',
#  'restablecer',
#  'afán',
#  'reestructuración',
#  'patriota',
#  'digno',
#  'floración',
#  'aspiraciones',
#  'calma',
#  'gradual',
#  'estímulo',
#  'bonus',
#  'modesto',
#  'remedio',
#  'autorizado',
#  'inmenso',
#  'originalidad',
#  'crianza',
#  'limpiar',
#  'portátil',
#  'flexibilidad',
#  'profundidades',
#  'razonable',
#  'consorcio',
#  'conveniencia',
#  'adoración',
#  'hábil',
#  'poético',
#  'energético',
#  'magnífico',
#  'colorido',
#  'gratis',
#  'productiva',
#  'firmemente',
#  'erudito',
#  'recomendable',
#  'fantástico',
#  'lírico',
#  'aclamado',
#  'ganancia',
#  'progresista',
#  'maduro',
#  'coherente',
#  'afluencia',
#  'piedad',
#  'exitosamente',
#  'supremacía',
#  'impresionado',
#  'cooperativa',
#  'prestación',
#  'competitivo',
#  'prendas',
#  'apreciado',
#  'sobresaliente',
#  'rosado',
#  'productivo',
#  'limpio',
#  'amada',
#  'íntimo',
#  'divertido',
#  'mejoramiento',
#  'sumo',
#  'bendición',
#  'seguidor',
#  'asegurando',
#  'disminuido',
#  'indiscutible',
#  'love',
#  'descansar',
#  'profecía',
#  'pacífico',
#  'disfruta',
#  'aliviar',
#  'sustancial',
#  'valentía',
#  'sustento',
#  'milagros',
#  'comodidad',
#  'entusiasta',
#  'destreza',
#  'acoger',
#  'reconciliación',
#  'cláusula',
#  'acreditado',
#  'curación',
#  'boom',
#  'cuadra',
#  'obsesión',
#  'palanca',
#  'perpendicular',
#  'memorable',
#  'motivado',
#  'reformar',
#  'prenda',
#  'multa',
#  'victorioso',
#  'prolífico',
#  'liderar',
#  'liso',
#  'joya',
#  'amado',
#  'revivir',
#  'veracidad',
#  'sustantivo',
#  'óptimo',
#  'reformado',
#  'grandeza',
#  'elegancia',
#  'humorístico',
#  'barato',
#  'estimular',
#  'amoroso',
#  'sonrisa',
#  'confiar',
#  'sensaciones',
#  'alba',
#  'simplificado',
#  'genial',
#  'excepcionalmente',
#  'paciencia',
#  'sano',
#  'amar',
#  'recomendado',
#  'óptima',
#  'asegurado',
#  'maravilloso',
#  'surrealista',
#  'orgulloso',
#  'apasionado',
#  'superviviente',
#  'triunfal',
#  'coraje',
#  'sobreviviente',
#  'competente',
#  'apelación',
#  'actualizado',
#  'aspiración',
#  'maravillas',
#  'abogada',
#  'calificar',
#  'robusto',
#  'favorecido',
#  'compacta',
#  'satisfecho',
#  'coherencia',
#  'devolución',
#  'provecho',
#  'aspirante',
#  'admirador',
#  'triunfar',
#  'trance',
#  'festivo',
#  'previsión',
#  'cómodo',
#  'like',
#  'suprema',
#  'valorar',
#  'navegable',
#  'best',
#  'sencillamente',
#  'agilidad',
#  'consecuentemente',
#  'ordenanza',
#  'ágil',
#  'disfrute',
#  'solid',
#  'versatilidad',
#  'bondad',
#  'carisma',
#  'free',
#  'medido',
#  'privilegiado',
#  'oasis',
#  'res',
#  'susceptible',
#  'trascendental',
#  'facilitando',
#  'sorprendentemente',
#  'bovino',
#  'enmienda',
#  'enriquecimiento',
#  'alivio',
#  'animar',
#  'progresos',
#  'guiar',
#  'ahorros',
#  'futurista',
#  'agrado',
#  'abrazo',
#  'bonito',
#  'honrar',
#  'formidable',
#  'honrado',
#  'oportuno',
#  'finamente',
#  'admirar',
#  'intimidad',
#  'ardiente',
#  'eminente',
#  'elite',
#  'aventurero',
#  'extraordinariamente',
#  'súper',
#  'subsiguiente',
#  'confiable',
#  'constructivo',
#  'preferible',
#  'complementar',
#  'refinado',
#  'generosidad',
#  'saludable',
#  'distinguirse',
#  'contento',
#  'factible',
#  'manada',
#  'sobrepasar',
#  'optimista',
#  'exento',
#  'moralidad',
#  'exuberante',
#  'propicio',
#  'luminoso',
#  'máster',
#  'excitación',
#  'caluroso',
#  'generoso',
#  'fielmente',
#  'devoto',
#  'versátil',
#  'virtuoso',
#  'buey',
#  'cortesía',
#  'gratitud',
#  'fervor',
#  'encender',
#  'borra',
#  'profusamente',
#  'disolvente',
#  'eternidad',
#  'preventiva',
#  'heroico',
#  'articular',
#  'prometedor',
#  'sensual',
#  'asombro',
#  'humildad',
#  'acierto',
#  'intriga',
#  'sofisticado',
#  'articulado',
#  'calmar',
#  'complementos',
#  'apreciable',
#  'sensiblemente',
#  'ajustado',
#  'instantáneamente',
#  'apego',
#  'prudente',
#  'estimula',
#  'afección',
#  'exaltación',
#  'abunda',
#  'pintoresco',
#  'perfeccionar',
#  'próspero',
#  'emocionante',
#  'estabilizar',
#  'cordial',
#  'madurar',
#  'celestial',
#  'satisface',
#  'alcohólico',
#  'curado',
#  'sexy',
#  'gozar',
#  'fascinación',
#  'ferviente',
#  'lujoso',
#  'escénico',
#  'inoxidable',
#  'triunfante',
#  'suavemente',
#  'prefiriendo',
#  'equilibrado',
#  'increíblemente',
#  'deseable',
#  'floreciente',
#  'simplificar',
#  'calentar',
#  'tremendamente',
#  'honestidad',
#  'sostenibilidad',
#  'eficazmente',
#  'espontáneo',
#  'complementario',
#  'inolvidable',
#  'diestro',
#  'disfrutando',
#  'respetable',
#  'encantado',
#  'superintendente',
#  'amistosa',
#  'mejoría',
#  'refinamiento',
#  'optimismo',
#  'selectivo',
#  'alabanza',
#  'redención',
#  'talentoso',
#  'prudencia',
#  'precioso',
#  'ayuno',
#  'simpático',
#  'diana',
#  'convincente',
#  'vigilante',
#  'amigable',
#  'aclamación',
#  'adelantar',
#  'pacíficamente',
#  'admirable',
#  'misericordia',
#  'impecable',
#  'conciliar',
#  'indudable',
#  'convenientemente',
#  'rapto',
#  'aspirar',
#  'maravilla',
#  'consuelo',
#  'prodigio',
#  'suposición',
#  'master',
#  'excede',
#  'indulto',
#  'heredar',
#  'exhaustivo',
#  'benéfico',
#  'satisfactoriamente',
#  'honesto',
#  'vibrante',
#  'elogio',
#  'uniformemente',
#  'coronar',
#  'agradecido',
#  'carismático',
#  'honorable',
#  'enérgico',
#  'tenaz',
#  'merecedor',
#  'estimulante',
#  'auspicio',
#  'prominencia',
#  'patriótico',
#  'florecer',
#  'consumado',
#  'expresivo',
#  'sustentación',
#  'fragilidad',
#  'ingenioso',
#  'ricamente',
#  'cofre',
#  'beneficioso',
#  'confidente',
#  'éxtasis',
#  'respaldar',
#  'progresar',
#  'profusión',
#  'gracioso',
#  'benefactor',
#  'premiar',
#  'cooperativo',
#  'glorioso',
#  'caramelo',
#  'empujar',
#  'fascinante',
#  'invencible',
#  'ilimitado',
#  'permitirse',
#  'comprensible',
#  'majestad',
#  'deseando',
#  'milagrosamente',
#  'afortunadamente',
#  'atento',
#  'pera',
#  'sincero',
#  'sublime',
#  'razonablemente',
#  'satisfactorio',
#  'empatía',
#  'exquisito',
#  'silencioso',
#  'agradecer',
#  'obertura',
#  'nata',
#  'emprendedor',
#  'autorizar',
#  'serenidad',
#  ...]

# %%
# palabras unicas / palabras totales
def redundancia(str): 
    # break the string into list of words 
    str = str.split()
    str2 = [] 
    # loop till string values present in list str 
    for i in range (0, len (str)): 
        # checking for the duplicacy 
        if str[i] not in str2: 
            # insert value in str2 
            str2.append(str[i])
 
    rta = len(str2)/len(str) 
            
    return rta

# %%
redundancia('hola me llamo diany a a a a a a ')
# Out:
# hola
# me
# llamo
# diany
# a
# 5
# 10
# 0.5
